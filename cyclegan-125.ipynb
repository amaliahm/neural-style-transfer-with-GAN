# %% [markdown]
# ## Libraries

# %%
# !pip install lpips
# Out:
# Collecting lpips
#   Downloading lpips-0.1.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from lpips) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from lpips) (0.21.0+cu124)
# Requirement already satisfied: numpy>=1.14.3 in /usr/local/lib/python3.11/dist-packages (from lpips) (1.26.4)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from lpips) (1.15.3)
# Requirement already satisfied: tqdm>=4.28.1 in /usr/local/lib/python3.11/dist-packages (from lpips) (4.67.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.14.3->lpips) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.14.3->lpips) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.14.3->lpips) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.14.3->lpips) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.14.3->lpips) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.14.3->lpips) (2.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=0.4.0->lpips) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=0.4.0->lpips) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=0.4.0->lpips) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=0.4.0->lpips) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=0.4.0->lpips) (2025.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=0.4.0->lpips)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=0.4.0->lpips)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=0.4.0->lpips)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=0.4.0->lpips)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=0.4.0->lpips)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=0.4.0->lpips)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=0.4.0->lpips)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=0.4.0->lpips)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=0.4.0->lpips)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=0.4.0->lpips) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=0.4.0->lpips) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=0.4.0->lpips) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=0.4.0->lpips)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=0.4.0->lpips) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=0.4.0->lpips) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=0.4.0->lpips) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision>=0.2.1->lpips) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=0.4.0->lpips) (3.0.3)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.14.3->lpips) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.14.3->lpips) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.14.3->lpips) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.14.3->lpips) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.14.3->lpips) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.14.3->lpips) (2024.2.0)
# Downloading lpips-0.1.4-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 1.9 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 111.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 34.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 14.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 9.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 100.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, lpips
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed lpips-0.1.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torchvision import transforms
import torchvision.utils as vutils
import matplotlib.pyplot as plt
import torch.optim as optim
import torch.nn as nn
from PIL import Image
import torch
import lpips
import time
import os

# %%
# resize to 256x256 and normalize to [-1, 1]
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),  # converts to [0,1]
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # converts to [-1, 1]
])

# %%
class ImageDataset(Dataset):
    def __init__(self, root_A, root_B, transform=None):
        self.transform = transform
        self.files_A = sorted([os.path.join(root_A, f) for f in os.listdir(root_A) if f.endswith(".jpg")])
        self.files_B = sorted([os.path.join(root_B, f) for f in os.listdir(root_B) if f.endswith(".jpg")])

    def __len__(self):
        return min(len(self.files_A), len(self.files_B))

    def __getitem__(self, idx):
        img_A = Image.open(self.files_A[idx]).convert("RGB")
        img_B = Image.open(self.files_B[idx]).convert("RGB")

        if self.transform:
            img_A = self.transform(img_A)
            img_B = self.transform(img_B)

        return {"A": img_A, "B": img_B}

# %%
dataset = ImageDataset("/kaggle/input/monet2photo/trainA", "/kaggle/input/monet2photo/trainB", transform=transform)

# %%
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)

# %%
for i, batch in enumerate(dataloader):
    print(batch["A"].shape, batch["B"].shape)
    break
# Out:
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])

# %% [markdown]
# ## Generator

# %%
class ResnetBlock(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.block = nn.Sequential(
            nn.ReflectionPad2d(1), # padding to preserve spatial size
            nn.Conv2d(dim, dim, 3), # first conv layer
            nn.InstanceNorm2d(dim), # normalization 
            nn.ReLU(inplace=True), # activation with ReLU
            nn.ReflectionPad2d(1), # padding
            nn.Conv2d(dim, dim, 3), # second conv layer
            nn.InstanceNorm2d(dim), # normalization
        )

    def forward(self, x):
        return x + self.block(x)

# full ResNet generator --part 1
class ResnetGenerator(nn.Module):
    def __init__(self, in_channels=3, out_channels=3, n_blocks=9):
        super().__init__()

        # encoder (initial conv block)
        model = [
            nn.ReflectionPad2d(3), # padding
            nn.Conv2d(in_channels, 64, 7), # large kernel in order to capture more features
            nn.InstanceNorm2d(64),
            nn.ReLU(inplace=True),
        ]
        # encoder --part 2: downsampling layers
        in_features = 64
        for _ in range(2):
            out_features = in_features * 2
            model += [
                nn.Conv2d(in_features, out_features, 3, stride=2, padding=1),
                nn.InstanceNorm2d(out_features),
                nn.ReLU(inplace=True),
            ]
            in_features = out_features

        # transformation layers (ResNet blocks)
        for _ in range(n_blocks): # n_block = 9
            model += [ResnetBlock(in_features)]

        # decoder: upsampling layers
        for _ in range(2):
            out_features = in_features // 2
            model += [
                nn.ConvTranspose2d(in_features, out_features, 3, stride=2, padding=1, output_padding=1),
                nn.InstanceNorm2d(out_features),
                nn.ReLU(inplace=True),
            ]
            in_features = out_features

        # output layer
        model += [
            nn.ReflectionPad2d(3), # padding
            nn.Conv2d(64, out_channels, 7), # out_channels = 3
            nn.Tanh() # for normalization the output to [-1, 1]
        ]

        self.model = nn.Sequential(*model)

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## Discriminator

# %%
# PatchGAN Discriminator
class PatchDiscriminator(nn.Module):
    def __init__(self, in_channels=3):
        super().__init__()

        # helper function to define a conv layer
        def block(in_feat, out_feat, norm=True):
            layers = [nn.Conv2d(in_feat, out_feat, 4, stride=2, padding=1)]
            if norm:
                layers.append(nn.InstanceNorm2d(out_feat)) # apply normalization if needed
            layers.append(nn.LeakyReLU(0.2, inplace=True)) # ReLU activation
            return layers

        # the discriminator model as a series of conv layers
        self.model = nn.Sequential(
            *block(in_channels, 64, norm=False), # first layer without normalization (as mentionned on the original paper)
            *block(64, 128), 
            *block(128, 256),
            *block(256, 512),
            nn.Conv2d(512, 1, 4, padding=1) # final output layer with single channel output (real or fake)
        )

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## Loss functions

# %% [markdown]
# ### Adversarial Loss

# %%
adv_criterion = nn.MSELoss()

# %% [markdown]
# ### Cycle Consistency Loss

# %%
cycle_criterion = nn.L1Loss()

# %% [markdown]
# ### Identity loss

# %%
identity_criterion = nn.L1Loss()

# %% [markdown]
# ## Training loop

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
G_A2B = ResnetGenerator().to(device)
G_B2A = ResnetGenerator().to(device)
D_A = PatchDiscriminator().to(device)
D_B = PatchDiscriminator().to(device)

# %%
optimizer_G = optim.Adam(
    list(G_A2B.parameters()) + list(G_B2A.parameters()), 
    lr=0.0002, 
    betas=(0.5, 0.999)
)

optimizer_D_A = optim.Adam(D_A.parameters(), lr=0.0002, betas=(0.5, 0.999))
optimizer_D_B = optim.Adam(D_B.parameters(), lr=0.0002, betas=(0.5, 0.999))

# %%
lambda_identity = 5.0
lambda_cycle = 10.0
num_epochs = 120

# %%
G_losses = []
D_A_losses = []
D_B_losses = []
epoch_times = []

# %%
for epoch in range(num_epochs):
    epoch_start_time = time.time() # start time of epoch
    total_loss_G = 0
    total_loss_D_A = 0
    total_loss_D_B = 0
    total_batches = len(dataloader)

    for batch_idx, batch in enumerate(dataloader):
        batch_start_time = time.time()  # start time of batch

        real_A = batch["A"].to(device)
        real_B = batch["B"].to(device)

        # train generators
        optimizer_G.zero_grad()

        # identity loss
        same_B = G_A2B(real_B)
        same_A = G_B2A(real_A)
        loss_id_A = identity_criterion(same_A, real_A) * lambda_identity
        loss_id_B = identity_criterion(same_B, real_B) * lambda_identity

        # adversarial loss
        fake_B = G_A2B(real_A)
        pred_fake_B = D_B(fake_B)
        loss_GAN_A2B = adv_criterion(pred_fake_B, torch.ones_like(pred_fake_B))

        fake_A = G_B2A(real_B)
        pred_fake_A = D_A(fake_A)
        loss_GAN_B2A = adv_criterion(pred_fake_A, torch.ones_like(pred_fake_A))

        # cycle consistency loss
        rec_A = G_B2A(fake_B)
        rec_B = G_A2B(fake_A)
        loss_cycle_A = cycle_criterion(rec_A, real_A) * lambda_cycle
        loss_cycle_B = cycle_criterion(rec_B, real_B) * lambda_cycle

        # total generator loss
        loss_G = loss_id_A + loss_id_B + loss_GAN_A2B + loss_GAN_B2A + loss_cycle_A + loss_cycle_B
        loss_G.backward()
        optimizer_G.step()

        # train discriminators
        optimizer_D_A.zero_grad()
        pred_real_A = D_A(real_A)
        pred_fake_A = D_A(fake_A.detach())
        loss_D_real_A = adv_criterion(pred_real_A, torch.ones_like(pred_real_A))
        loss_D_fake_A = adv_criterion(pred_fake_A, torch.zeros_like(pred_fake_A))
        loss_D_A = (loss_D_real_A + loss_D_fake_A) * 0.5
        loss_D_A.backward()
        optimizer_D_A.step()

        optimizer_D_B.zero_grad()
        pred_real_B = D_B(real_B)
        pred_fake_B = D_B(fake_B.detach())
        loss_D_real_B = adv_criterion(pred_real_B, torch.ones_like(pred_real_B))
        loss_D_fake_B = adv_criterion(pred_fake_B, torch.zeros_like(pred_fake_B))
        loss_D_B = (loss_D_real_B + loss_D_fake_B) * 0.5
        loss_D_B.backward()
        optimizer_D_B.step()

        # accumulate losses
        total_loss_G += loss_G.item()
        total_loss_D_A += loss_D_A.item()
        total_loss_D_B += loss_D_B.item()

        # time running per batch
        batch_time = time.time() - batch_start_time
        remaining_batches = total_batches - (batch_idx + 1)
        estimated_time_left = batch_time * remaining_batches
        print(f"Batch {batch_idx+1}/{total_batches} completed in {batch_time:.2f} seconds. Estimated time left: {estimated_time_left/60:.2f} minutes.", end='\r')

    epoch_end_time = time.time()
    epoch_duration = epoch_end_time - epoch_start_time
    G_losses.append(total_loss_G / total_batches)
    D_A_losses.append(total_loss_D_A / total_batches)
    D_B_losses.append(total_loss_D_B / total_batches)
    epoch_times.append(epoch_duration / 60)

    print(f"\nEpoch [{epoch+1}/{num_epochs}] completed in {epoch_duration/60:.2f} minutes.")
    print(f"  Generator Loss: {total_loss_G/total_batches:.4f}")
    print(f"  Discriminator A Loss: {total_loss_D_A/total_batches:.4f}")
    print(f"  Discriminator B Loss: {total_loss_D_B/total_batches:.4f}")
# Out:
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [1/120] completed in 5.81 minutes.
#   Generator Loss: 9.5580
#   Discriminator A Loss: 0.2277
#   Discriminator B Loss: 0.2268
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [2/120] completed in 5.68 minutes.
#   Generator Loss: 8.3818
#   Discriminator A Loss: 0.1998
#   Discriminator B Loss: 0.2039
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [3/120] completed in 5.68 minutes.
#   Generator Loss: 7.7560
#   Discriminator A Loss: 0.1988
#   Discriminator B Loss: 0.1930
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [4/120] completed in 5.68 minutes.
#   Generator Loss: 7.4378
#   Discriminator A Loss: 0.1950
#   Discriminator B Loss: 0.1878
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [5/120] completed in 5.68 minutes.
#   Generator Loss: 7.2322
#   Discriminator A Loss: 0.1894
#   Discriminator B Loss: 0.1854
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [6/120] completed in 5.68 minutes.
#   Generator Loss: 7.1693
#   Discriminator A Loss: 0.1817
#   Discriminator B Loss: 0.1749
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [7/120] completed in 5.68 minutes.
#   Generator Loss: 6.9932
#   Discriminator A Loss: 0.1763
#   Discriminator B Loss: 0.1765
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [8/120] completed in 5.68 minutes.
#   Generator Loss: 6.8467
#   Discriminator A Loss: 0.1737
#   Discriminator B Loss: 0.1724
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [9/120] completed in 5.68 minutes.
#   Generator Loss: 6.8299
#   Discriminator A Loss: 0.1528
#   Discriminator B Loss: 0.1725
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [10/120] completed in 5.67 minutes.
#   Generator Loss: 6.8140
#   Discriminator A Loss: 0.1265
#   Discriminator B Loss: 0.1660
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [11/120] completed in 5.67 minutes.
#   Generator Loss: 6.7186
#   Discriminator A Loss: 0.1195
#   Discriminator B Loss: 0.1672
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [12/120] completed in 5.68 minutes.
#   Generator Loss: 6.6133
#   Discriminator A Loss: 0.1099
#   Discriminator B Loss: 0.1647
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [13/120] completed in 5.68 minutes.
#   Generator Loss: 6.5260
#   Discriminator A Loss: 0.0997
#   Discriminator B Loss: 0.1634
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [14/120] completed in 5.68 minutes.
#   Generator Loss: 6.4134
#   Discriminator A Loss: 0.0972
#   Discriminator B Loss: 0.1611
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [15/120] completed in 5.68 minutes.
#   Generator Loss: 6.3569
#   Discriminator A Loss: 0.0966
#   Discriminator B Loss: 0.1595
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [16/120] completed in 5.68 minutes.
#   Generator Loss: 6.3618
#   Discriminator A Loss: 0.0889
#   Discriminator B Loss: 0.1513
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [17/120] completed in 5.68 minutes.
#   Generator Loss: 6.2961
#   Discriminator A Loss: 0.0904
#   Discriminator B Loss: 0.1529
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [18/120] completed in 5.67 minutes.
#   Generator Loss: 6.2350
#   Discriminator A Loss: 0.0890
#   Discriminator B Loss: 0.1486
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [19/120] completed in 5.67 minutes.
#   Generator Loss: 6.1911
#   Discriminator A Loss: 0.0828
#   Discriminator B Loss: 0.1515
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [20/120] completed in 5.67 minutes.
#   Generator Loss: 6.1408
#   Discriminator A Loss: 0.0847
#   Discriminator B Loss: 0.1469
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [21/120] completed in 5.67 minutes.
#   Generator Loss: 6.0766
#   Discriminator A Loss: 0.0790
#   Discriminator B Loss: 0.1469
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [22/120] completed in 5.69 minutes.
#   Generator Loss: 6.0492
#   Discriminator A Loss: 0.0768
#   Discriminator B Loss: 0.1435
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [23/120] completed in 5.70 minutes.
#   Generator Loss: 6.0321
#   Discriminator A Loss: 0.0781
#   Discriminator B Loss: 0.1358
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [24/120] completed in 5.68 minutes.
#   Generator Loss: 6.0010
#   Discriminator A Loss: 0.0732
#   Discriminator B Loss: 0.1367
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [25/120] completed in 5.67 minutes.
#   Generator Loss: 5.9591
#   Discriminator A Loss: 0.0737
#   Discriminator B Loss: 0.1327
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [26/120] completed in 5.67 minutes.
#   Generator Loss: 5.9140
#   Discriminator A Loss: 0.0720
#   Discriminator B Loss: 0.1325
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [27/120] completed in 5.68 minutes.
#   Generator Loss: 5.8994
#   Discriminator A Loss: 0.0688
#   Discriminator B Loss: 0.1272
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [28/120] completed in 5.68 minutes.
#   Generator Loss: 5.8832
#   Discriminator A Loss: 0.0652
#   Discriminator B Loss: 0.1260
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [29/120] completed in 5.67 minutes.
#   Generator Loss: 5.8433
#   Discriminator A Loss: 0.0624
#   Discriminator B Loss: 0.1232
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [30/120] completed in 5.68 minutes.
#   Generator Loss: 5.8253
#   Discriminator A Loss: 0.0622
#   Discriminator B Loss: 0.1172
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [31/120] completed in 5.68 minutes.
#   Generator Loss: 5.7952
#   Discriminator A Loss: 0.0595
#   Discriminator B Loss: 0.1174
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [32/120] completed in 5.69 minutes.
#   Generator Loss: 5.8006
#   Discriminator A Loss: 0.0556
#   Discriminator B Loss: 0.1158
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [33/120] completed in 5.69 minutes.
#   Generator Loss: 5.7299
#   Discriminator A Loss: 0.0560
#   Discriminator B Loss: 0.1125
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [34/120] completed in 5.68 minutes.
#   Generator Loss: 5.7143
#   Discriminator A Loss: 0.0574
#   Discriminator B Loss: 0.1100
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [35/120] completed in 5.67 minutes.
#   Generator Loss: 5.6790
#   Discriminator A Loss: 0.0552
#   Discriminator B Loss: 0.1102
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [36/120] completed in 5.67 minutes.
#   Generator Loss: 5.6653
#   Discriminator A Loss: 0.0561
#   Discriminator B Loss: 0.1064
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [37/120] completed in 5.67 minutes.
#   Generator Loss: 5.5673
#   Discriminator A Loss: 0.0573
#   Discriminator B Loss: 0.1062
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [38/120] completed in 5.66 minutes.
#   Generator Loss: 5.5670
#   Discriminator A Loss: 0.0583
#   Discriminator B Loss: 0.1022
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [39/120] completed in 5.66 minutes.
#   Generator Loss: 5.5634
#   Discriminator A Loss: 0.0629
#   Discriminator B Loss: 0.0978
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [40/120] completed in 5.67 minutes.
#   Generator Loss: 5.4720
#   Discriminator A Loss: 0.0654
#   Discriminator B Loss: 0.1034
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [41/120] completed in 5.66 minutes.
#   Generator Loss: 5.4611
#   Discriminator A Loss: 0.0717
#   Discriminator B Loss: 0.0994
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [42/120] completed in 5.67 minutes.
#   Generator Loss: 5.4068
#   Discriminator A Loss: 0.0723
#   Discriminator B Loss: 0.0954
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [43/120] completed in 5.70 minutes.
#   Generator Loss: 5.4024
#   Discriminator A Loss: 0.0771
#   Discriminator B Loss: 0.0975
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [44/120] completed in 5.68 minutes.
#   Generator Loss: 5.3906
#   Discriminator A Loss: 0.0793
#   Discriminator B Loss: 0.0954
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [45/120] completed in 5.69 minutes.
#   Generator Loss: 5.4014
#   Discriminator A Loss: 0.0792
#   Discriminator B Loss: 0.0940
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [46/120] completed in 5.69 minutes.
#   Generator Loss: 5.3430
#   Discriminator A Loss: 0.0794
#   Discriminator B Loss: 0.0942
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [47/120] completed in 5.68 minutes.
#   Generator Loss: 5.3393
#   Discriminator A Loss: 0.0805
#   Discriminator B Loss: 0.0957
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [48/120] completed in 5.69 minutes.
#   Generator Loss: 5.2844
#   Discriminator A Loss: 0.0775
#   Discriminator B Loss: 0.0950
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [49/120] completed in 5.70 minutes.
#   Generator Loss: 5.2954
#   Discriminator A Loss: 0.0775
#   Discriminator B Loss: 0.0920
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [50/120] completed in 5.68 minutes.
#   Generator Loss: 5.2993
#   Discriminator A Loss: 0.0762
#   Discriminator B Loss: 0.0928
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [51/120] completed in 5.68 minutes.
#   Generator Loss: 5.2521
#   Discriminator A Loss: 0.0768
#   Discriminator B Loss: 0.0903
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [52/120] completed in 5.69 minutes.
#   Generator Loss: 5.2353
#   Discriminator A Loss: 0.0773
#   Discriminator B Loss: 0.0909
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [53/120] completed in 5.69 minutes.
#   Generator Loss: 5.2263
#   Discriminator A Loss: 0.0771
#   Discriminator B Loss: 0.0921
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [54/120] completed in 5.71 minutes.
#   Generator Loss: 5.2226
#   Discriminator A Loss: 0.0775
#   Discriminator B Loss: 0.0887
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [55/120] completed in 5.70 minutes.
#   Generator Loss: 5.1603
#   Discriminator A Loss: 0.0763
#   Discriminator B Loss: 0.0913
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [56/120] completed in 5.69 minutes.
#   Generator Loss: 5.1658
#   Discriminator A Loss: 0.0726
#   Discriminator B Loss: 0.0912
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [57/120] completed in 5.70 minutes.
#   Generator Loss: 5.1548
#   Discriminator A Loss: 0.0734
#   Discriminator B Loss: 0.0877
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [58/120] completed in 5.69 minutes.
#   Generator Loss: 5.1417
#   Discriminator A Loss: 0.0711
#   Discriminator B Loss: 0.0913
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [59/120] completed in 5.69 minutes.
#   Generator Loss: 5.1430
#   Discriminator A Loss: 0.0707
#   Discriminator B Loss: 0.0892
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [60/120] completed in 5.70 minutes.
#   Generator Loss: 5.1173
#   Discriminator A Loss: 0.0728
#   Discriminator B Loss: 0.0871
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [61/120] completed in 5.71 minutes.
#   Generator Loss: 5.1203
#   Discriminator A Loss: 0.0709
#   Discriminator B Loss: 0.0869
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [62/120] completed in 5.70 minutes.
#   Generator Loss: 5.0281
#   Discriminator A Loss: 0.0745
#   Discriminator B Loss: 0.0884
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [63/120] completed in 5.70 minutes.
#   Generator Loss: 5.0783
#   Discriminator A Loss: 0.0699
#   Discriminator B Loss: 0.0873
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [64/120] completed in 5.70 minutes.
#   Generator Loss: 5.0452
#   Discriminator A Loss: 0.0711
#   Discriminator B Loss: 0.0884
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [65/120] completed in 5.70 minutes.
#   Generator Loss: 5.0316
#   Discriminator A Loss: 0.0671
#   Discriminator B Loss: 0.0895
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [66/120] completed in 5.74 minutes.
#   Generator Loss: 5.0002
#   Discriminator A Loss: 0.0682
#   Discriminator B Loss: 0.0860
# Batch 1072/1072 completed in 0.32 seconds. Estimated time left: 0.00 minutes.
# Epoch [67/120] completed in 5.77 minutes.
#   Generator Loss: 5.0042
#   Discriminator A Loss: 0.0675
#   Discriminator B Loss: 0.0869
# Batch 1072/1072 completed in 0.32 seconds. Estimated time left: 0.00 minutes.
# Epoch [68/120] completed in 5.75 minutes.
#   Generator Loss: 5.0126
#   Discriminator A Loss: 0.0653
#   Discriminator B Loss: 0.0857
# Batch 1072/1072 completed in 0.32 seconds. Estimated time left: 0.00 minutes.
# Epoch [69/120] completed in 5.75 minutes.
#   Generator Loss: 4.9294
#   Discriminator A Loss: 0.0676
#   Discriminator B Loss: 0.0895
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [70/120] completed in 5.71 minutes.
#   Generator Loss: 4.9586
#   Discriminator A Loss: 0.0646
#   Discriminator B Loss: 0.0880
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [71/120] completed in 5.70 minutes.
#   Generator Loss: 4.9333
#   Discriminator A Loss: 0.0657
#   Discriminator B Loss: 0.0870
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [72/120] completed in 5.69 minutes.
#   Generator Loss: 4.9408
#   Discriminator A Loss: 0.0647
#   Discriminator B Loss: 0.0868
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [73/120] completed in 5.69 minutes.
#   Generator Loss: 4.9069
#   Discriminator A Loss: 0.0659
#   Discriminator B Loss: 0.0899
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [74/120] completed in 5.68 minutes.
#   Generator Loss: 4.9248
#   Discriminator A Loss: 0.0668
#   Discriminator B Loss: 0.0854
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [75/120] completed in 5.68 minutes.
#   Generator Loss: 4.8997
#   Discriminator A Loss: 0.0613
#   Discriminator B Loss: 0.0880
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [76/120] completed in 5.68 minutes.
#   Generator Loss: 4.8697
#   Discriminator A Loss: 0.0669
#   Discriminator B Loss: 0.0866
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [77/120] completed in 5.69 minutes.
#   Generator Loss: 4.8488
#   Discriminator A Loss: 0.0655
#   Discriminator B Loss: 0.0892
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [78/120] completed in 5.70 minutes.
#   Generator Loss: 4.8840
#   Discriminator A Loss: 0.0616
#   Discriminator B Loss: 0.0858
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [79/120] completed in 5.71 minutes.
#   Generator Loss: 4.8508
#   Discriminator A Loss: 0.0647
#   Discriminator B Loss: 0.0903
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [80/120] completed in 5.72 minutes.
#   Generator Loss: 4.8835
#   Discriminator A Loss: 0.0632
#   Discriminator B Loss: 0.0847
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [81/120] completed in 5.72 minutes.
#   Generator Loss: 4.8129
#   Discriminator A Loss: 0.0636
#   Discriminator B Loss: 0.0915
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [82/120] completed in 5.72 minutes.
#   Generator Loss: 4.7902
#   Discriminator A Loss: 0.0633
#   Discriminator B Loss: 0.0905
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [83/120] completed in 5.72 minutes.
#   Generator Loss: 4.8075
#   Discriminator A Loss: 0.0626
#   Discriminator B Loss: 0.0882
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [84/120] completed in 5.71 minutes.
#   Generator Loss: 4.8100
#   Discriminator A Loss: 0.0625
#   Discriminator B Loss: 0.0868
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [85/120] completed in 5.72 minutes.
#   Generator Loss: 4.7868
#   Discriminator A Loss: 0.0636
#   Discriminator B Loss: 0.0896
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [86/120] completed in 5.72 minutes.
#   Generator Loss: 4.7629
#   Discriminator A Loss: 0.0608
#   Discriminator B Loss: 0.0901
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [87/120] completed in 5.72 minutes.
#   Generator Loss: 4.7442
#   Discriminator A Loss: 0.0621
#   Discriminator B Loss: 0.0917
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [88/120] completed in 5.72 minutes.
#   Generator Loss: 4.7435
#   Discriminator A Loss: 0.0600
#   Discriminator B Loss: 0.0912
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [89/120] completed in 5.72 minutes.
#   Generator Loss: 4.7230
#   Discriminator A Loss: 0.0641
#   Discriminator B Loss: 0.0910
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [90/120] completed in 5.72 minutes.
#   Generator Loss: 4.7107
#   Discriminator A Loss: 0.0601
#   Discriminator B Loss: 0.0919
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [91/120] completed in 5.72 minutes.
#   Generator Loss: 4.6991
#   Discriminator A Loss: 0.0633
#   Discriminator B Loss: 0.0919
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [92/120] completed in 5.71 minutes.
#   Generator Loss: 4.6928
#   Discriminator A Loss: 0.0601
#   Discriminator B Loss: 0.0934
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [93/120] completed in 5.71 minutes.
#   Generator Loss: 4.7197
#   Discriminator A Loss: 0.0577
#   Discriminator B Loss: 0.0897
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [94/120] completed in 5.70 minutes.
#   Generator Loss: 4.6646
#   Discriminator A Loss: 0.0629
#   Discriminator B Loss: 0.0916
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [95/120] completed in 5.70 minutes.
#   Generator Loss: 4.6848
#   Discriminator A Loss: 0.0604
#   Discriminator B Loss: 0.0919
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [96/120] completed in 5.70 minutes.
#   Generator Loss: 4.6692
#   Discriminator A Loss: 0.0597
#   Discriminator B Loss: 0.0934
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [97/120] completed in 5.70 minutes.
#   Generator Loss: 4.6549
#   Discriminator A Loss: 0.0602
#   Discriminator B Loss: 0.0943
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [98/120] completed in 5.71 minutes.
#   Generator Loss: 4.6780
#   Discriminator A Loss: 0.0584
#   Discriminator B Loss: 0.0885
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [99/120] completed in 5.70 minutes.
#   Generator Loss: 4.6190
#   Discriminator A Loss: 0.0624
#   Discriminator B Loss: 0.0949
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [100/120] completed in 5.70 minutes.
#   Generator Loss: 4.6052
#   Discriminator A Loss: 0.0609
#   Discriminator B Loss: 0.0954
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [101/120] completed in 5.69 minutes.
#   Generator Loss: 4.6093
#   Discriminator A Loss: 0.0633
#   Discriminator B Loss: 0.0952
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [102/120] completed in 5.69 minutes.
#   Generator Loss: 4.6201
#   Discriminator A Loss: 0.0618
#   Discriminator B Loss: 0.0925
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [103/120] completed in 5.68 minutes.
#   Generator Loss: 4.5745
#   Discriminator A Loss: 0.0610
#   Discriminator B Loss: 0.0988
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [104/120] completed in 5.74 minutes.
#   Generator Loss: 4.5880
#   Discriminator A Loss: 0.0628
#   Discriminator B Loss: 0.0958
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [105/120] completed in 5.74 minutes.
#   Generator Loss: 4.5599
#   Discriminator A Loss: 0.0627
#   Discriminator B Loss: 0.0969
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [106/120] completed in 5.69 minutes.
#   Generator Loss: 4.5614
#   Discriminator A Loss: 0.0633
#   Discriminator B Loss: 0.0951
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [107/120] completed in 5.69 minutes.
#   Generator Loss: 4.5550
#   Discriminator A Loss: 0.0637
#   Discriminator B Loss: 0.0962
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [108/120] completed in 5.70 minutes.
#   Generator Loss: 4.5336
#   Discriminator A Loss: 0.0640
#   Discriminator B Loss: 0.0988
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [109/120] completed in 5.70 minutes.
#   Generator Loss: 4.5275
#   Discriminator A Loss: 0.0644
#   Discriminator B Loss: 0.0991
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [110/120] completed in 5.70 minutes.
#   Generator Loss: 4.5253
#   Discriminator A Loss: 0.0659
#   Discriminator B Loss: 0.0978
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [111/120] completed in 5.71 minutes.
#   Generator Loss: 4.5130
#   Discriminator A Loss: 0.0681
#   Discriminator B Loss: 0.0975
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [112/120] completed in 5.70 minutes.
#   Generator Loss: 4.5074
#   Discriminator A Loss: 0.0646
#   Discriminator B Loss: 0.0977
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [113/120] completed in 5.69 minutes.
#   Generator Loss: 4.4910
#   Discriminator A Loss: 0.0657
#   Discriminator B Loss: 0.0984
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [114/120] completed in 5.71 minutes.
#   Generator Loss: 4.4721
#   Discriminator A Loss: 0.0660
#   Discriminator B Loss: 0.1012
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [115/120] completed in 5.71 minutes.
#   Generator Loss: 4.4716
#   Discriminator A Loss: 0.0687
#   Discriminator B Loss: 0.0994
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [116/120] completed in 5.71 minutes.
#   Generator Loss: 4.4485
#   Discriminator A Loss: 0.0674
#   Discriminator B Loss: 0.1019
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [117/120] completed in 5.70 minutes.
#   Generator Loss: 4.4787
#   Discriminator A Loss: 0.0683
#   Discriminator B Loss: 0.0999
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [118/120] completed in 5.70 minutes.
#   Generator Loss: 4.4482
#   Discriminator A Loss: 0.0705
#   Discriminator B Loss: 0.0995
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [119/120] completed in 5.69 minutes.
#   Generator Loss: 4.4559
#   Discriminator A Loss: 0.0692
#   Discriminator B Loss: 0.1011
# Batch 1072/1072 completed in 0.31 seconds. Estimated time left: 0.00 minutes.
# Epoch [120/120] completed in 5.73 minutes.
#   Generator Loss: 4.4272
#   Discriminator A Loss: 0.0691
#   Discriminator B Loss: 0.1025

# %% [markdown]
# ### Save models

# %%
torch.save(G_A2B.state_dict(), "G_A2B.pth")
torch.save(G_B2A.state_dict(), "G_B2A.pth")
torch.save(D_A.state_dict(), "D_A.pth")
torch.save(D_B.state_dict(), "D_B.pth")

# %% [markdown]
# ## Evaluation

# %%
epochs = range(1, num_epochs + 1)
plt.figure(figsize=(12, 6))

# generator loss
plt.plot(epochs, G_losses, label='Generator Loss', marker='o')

# discriminator losses
plt.plot(epochs, D_A_losses, label='Discriminator A Loss', marker='x')
plt.plot(epochs, D_B_losses, label='Discriminator B Loss', marker='s')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Losses Over Epochs')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
epochs = range(1, num_epochs + 1)

plt.figure(figsize=(12, 6))

# discriminator losses
plt.plot(epochs, D_A_losses, label='Discriminator A Loss', marker='x')
plt.plot(epochs, D_B_losses, label='Discriminator B Loss', marker='s')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Losses Over Epochs')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
epochs = range(1, num_epochs + 1)

plt.figure(figsize=(12, 6))
plt.plot(epochs, epoch_times, label='Epoch Duration (min)', marker='D', color='purple')
plt.xlabel('Epoch')
plt.ylabel('Time (minutes)')
plt.title('Running Time per Epoch')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Testing phase

# %%
test_dataset = ImageDataset("/kaggle/input/monet2photo/testA", "/kaggle/input/monet2photo/testB", transform=transform)
test_dataloader = DataLoader(test_dataset, batch_size=1, shuffle=True)

# %%
def imshow(tensor, title):
    image = tensor.cpu().clone().detach()
    image = image.squeeze(0)
    image = (image + 1) / 2 
    np_img = image.numpy().transpose((1, 2, 0))
    plt.imshow(np_img)
    plt.title(title)
    plt.axis('off')

with torch.no_grad():
    for i, batch in enumerate(test_dataloader):
        if i >= 3: break  # show 3 examples

        real_A = batch["A"].to(device)
        real_B = batch["B"].to(device)

        fake_B = G_A2B(real_A)
        fake_A = G_B2A(real_B)

        plt.figure(figsize=(9, 6))

        plt.subplot(2, 3, 1)
        imshow(real_A[0], "Real A")

        plt.subplot(2, 3, 2)
        imshow(fake_B[0], "Fake B (A→B)")

        plt.subplot(2, 3, 3)
        imshow(G_B2A(fake_B)[0], "Reconstructed A")

        plt.subplot(2, 3, 4)
        imshow(real_B[0], "Real B")

        plt.subplot(2, 3, 5)
        imshow(fake_A[0], "Fake A (B→A)")

        plt.subplot(2, 3, 6)
        imshow(G_A2B(fake_A)[0], "Reconstructed B")

        plt.tight_layout()
        plt.show()

# %%
with torch.no_grad():
    total_cycle_loss = 0
    for batch in test_dataloader:
        real_A = batch["A"].to(device)
        real_B = batch["B"].to(device)

        fake_B = G_A2B(real_A)
        rec_A = G_B2A(fake_B)

        fake_A = G_B2A(real_B)
        rec_B = G_A2B(fake_A)

        loss_cycle_A = cycle_criterion(rec_A, real_A)
        loss_cycle_B = cycle_criterion(rec_B, real_B)

        total_cycle_loss += (loss_cycle_A + loss_cycle_B).item()

    avg_cycle_loss = total_cycle_loss / len(test_dataloader)
    print(f"Average Cycle Consistency Loss on Test Set: {avg_cycle_loss:.4f}")
# Out:
# Average Cycle Consistency Loss on Test Set: 0.2979

# %%
lpips_loss = lpips.LPIPS(net='alex').to(device)  # alexNet-based perceptual metric

def compute_lpips(model1, model2, dataloader):
    lpips_values = []
    model1.eval()
    model2.eval()
    for batch in dataloader:
        img = batch["A"].to(device)
        with torch.no_grad():
            translated = model1(img)
            cycled = model2(translated)
            loss = lpips_loss(img, cycled)
            lpips_values.append(loss.item())
    return sum(lpips_values) / len(lpips_values)

avg_lpips = compute_lpips(G_A2B, G_B2A, test_dataloader)
print(f"Average LPIPS: {avg_lpips:.4f}")
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:01<00:00, 189MB/s]
# Loading model from: /usr/local/lib/python3.11/dist-packages/lpips/weights/v0.1/alex.pth
# Average LPIPS: 0.4136

# %%
# !zip -r output.zip /kaggle/working/
# Out:
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/G_A2B.pth (deflated 7%)
#   adding: kaggle/working/__notebook__.ipynb (deflated 88%)
#   adding: kaggle/working/D_B.pth (deflated 7%)
#   adding: kaggle/working/D_A.pth (deflated 7%)
#   adding: kaggle/working/G_B2A.pth (deflated 7%)
